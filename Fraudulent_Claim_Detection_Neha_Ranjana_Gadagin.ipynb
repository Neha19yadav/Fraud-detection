# %% [markdown]
# ## **Fraudulent Claim Detection**

# %% [markdown]
# ## Problem Statement
# Global Insure, a leading insurance company, processes thousands of claims annually. However, a significant percentage of these claims turn out to be fraudulent, resulting in considerable financial losses. The company’s current process for identifying fraudulent claims involves manual inspections, which is time-consuming and inefficient. Fraudulent claims are often detected too late in the process, after the company has already paid out significant amounts. Global Insure wants to improve its fraud detection process using data-driven insights to classify claims as fraudulent or legitimate early in the approval process. This would minimise financial losses and optimise the overall claims handling process.
#
# ## Business Objective
# Global Insure wants to build a model to classify insurance claims as either fraudulent or legitimate based on historical claim details and customer profiles. By using features like claim amounts, customer profiles and claim types, the company aims to predict which claims are likely to be fraudulent before they are approved.
#
#
# Based on this assignment, you have to answer the following questions:<br>
#
# ● How can we analyse historical claim data to detect patterns that indicate fraudulent claims?<br>
# ● Which features are most predictive of fraudulent behaviour?<br>
# ● Can we predict the likelihood of fraud for an incoming claim, based on past data?<br>
# ● What insights can be drawn from the model that can help in improving the fraud detection process?<br>

# %% [markdown]
# ## Assignment Tasks
# You need to perform the following steps for successfully completing this assignment:
# 1. Data Preparation
# 2. Data Cleaning
# 3. Train Validation Split 70-30
# 4. EDA on Training Data
# 5. EDA on Validation Data (optional)
# 6. Feature Engineering
# 7. Model Building
# 8. Predicting and Model Evaluation

# %% [markdown]
# ## Data Dictionary
# The insurance claims data has 40 Columns and 1000 Rows. Following data dictionary provides the description for each column present in dataset:<br>
#
# <table>
#   <thead>
#     <tr>
#       <th>Column Name</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>months_as_customer</td>
#       <td>Represents the duration in months that a customer has been associated with the insurance company.</td>
#     </tr>
#     <tr>
#       <td>age</td>
#       <td>Represents the age of the insured person.</td>
#     </tr>
#     <tr>
#       <td>policy_number</td>
#       <td>Represents a unique identifier for each insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_bind_date</td>
#       <td>Represents the date when the insurance policy was initiated.</td>
#     </tr>
#     <tr>
#       <td>policy_state</td>
#       <td>Represents the state where the insurance policy is applicable.</td>
#     </tr>
#     <tr>
#       <td>policy_csl</td>
#       <td>Represents the combined single limit for the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>policy_deductable</td>
#       <td>Represents the amount that the insured person needs to pay before the insurance coverage kicks in.</td>
#     </tr>
#     <tr>
#       <td>policy_annual_premium</td>
#       <td>Represents the yearly cost of the insurance policy.</td>
#     </tr>
#     <tr>
#       <td>umbrella_limit</td>
#       <td>Represents an additional layer of liability coverage provided beyond the limits of the primary insurance policy.</td>
#     </tr>
#     <tr>
#       <td>insured_zip</td>
#       <td>Represents the zip code of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_sex</td>
#       <td>Represents the gender of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_education_level</td>
#       <td>Represents the highest educational qualification of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_occupation</td>
#       <td>Represents the profession or job of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_hobbies</td>
#       <td>Represents the hobbies or leisure activities of the insured person.</td>
#     </tr>
#     <tr>
#       <td>insured_relationship</td>
#       <td>Represents the relationship of the insured person to the policyholder.</td>
#     </tr>
#     <tr>
#       <td>capital-gains</td>
#       <td>Represents the profit earned from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>capital-loss</td>
#       <td>Represents the loss incurred from the sale of assets such as stocks, bonds, or real estate.</td>
#     </tr>
#     <tr>
#       <td>incident_date</td>
#       <td>Represents the date when the incident or accident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_type</td>
#       <td>Represents the category or type of incident that led to the claim.</td>
#     </tr>
#     <tr>
#       <td>collision_type</td>
#       <td>Represents the type of collision that occurred in an accident.</td>
#     </tr>
#     <tr>
#       <td>incident_severity</td>
#       <td>Represents the extent of damage or injury caused by the incident.</td>
#     </tr>
#     <tr>
#       <td>authorities_contacted</td>
#       <td>Represents the authorities or agencies that were contacted after the incident.</td>
#     </tr>
#     <tr>
#       <td>incident_state</td>
#       <td>Represents the state where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_city</td>
#       <td>Represents the city where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_location</td>
#       <td>Represents the specific location or address where the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>incident_hour_of_the_day</td>
#       <td>Represents the hour of the day when the incident occurred.</td>
#     </tr>
#     <tr>
#       <td>number_of_vehicles_involved</td>
#       <td>Represents the total number of vehicles involved in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_damage</td>
#       <td>Represents whether there was any damage to property in the incident.</td>
#     </tr>
#     <tr>
#       <td>bodily_injuries</td>
#       <td>Represents the number of bodily injuries resulting from the incident.</td>
#     </tr>
#     <tr>
#       <td>witnesses</td>
#       <td>Represents the number of witnesses present at the scene of the incident.</td>
#     </tr>
#     <tr>
#       <td>police_report_available</td>
#       <td>Represents whether a police report is available for the incident.</td>
#     </tr>
#     <tr>
#       <td>total_claim_amount</td>
#       <td>Represents the total amount claimed by the insured person for the incident.</td>
#     </tr>
#     <tr>
#       <td>injury_claim</td>
#       <td>Represents the amount claimed for injuries sustained in the incident.</td>
#     </tr>
#     <tr>
#       <td>property_claim</td>
#       <td>Represents the amount claimed for property damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>vehicle_claim</td>
#       <td>Represents the amount claimed for vehicle damage in the incident.</td>
#     </tr>
#     <tr>
#       <td>auto_make</td>
#       <td>Represents the manufacturer of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_model</td>
#       <td>Represents the specific model of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>auto_year</td>
#       <td>Represents the year of manufacture of the insured vehicle.</td>
#     </tr>
#     <tr>
#       <td>fraud_reported</td>
#       <td>Represents whether the claim was reported as fraudulent or not.</td>
#     </tr>
#     <tr>
#       <td>_c39</td>
#       <td>Represents an unknown or unspecified variable.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **1. Data Preparation**
# In this step, read the dataset provided in CSV format and look at basic statistics of the data, including preview of data, dimension of data, column descriptions and data types.

# %% [markdown]
# ### **1.0 Import Libraries**

# %%
# Supress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### **1.1 Load the Data**

# %%
# Load the dataset
df = pd.read_csv("insurance_claims.csv")

# %%
# Check at the first few entries
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0       466132  ...                     YES              71610         6510
# 1       468176  ...                       ?               5070          780
# 2       430632  ...                      NO              34650         7700
# 3       608117  ...                      NO              63400         6340
# 4       610706  ...                      NO               6500         1300
#
#   property_claim vehicle_claim  auto_make  auto_model auto_year  \
# 0          13020         52080       Saab         92x      2004
# 1            780          3510   Mercedes        E400      2007
# 2           3850         23100      Dodge         RAM      2007
# 3           6340         50720  Chevrolet       Tahoe      2014
# 4            650          4550     Accura         RSX      2009
#
#   fraud_reported _c39
# 0              Y  NaN
# 1              Y  NaN
# 2              N  NaN
# 3              Y  NaN
# 4              N  NaN
#
# [5 rows x 40 columns]

# %%
# Inspect the shape of the dataset
df.shape
# Out:
# (1000, 40)

# %%
# Inspect the features in the dataset
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %% [markdown]
# ## **2. Data Cleaning** <font color = red>[10 marks]</font>

# %% [markdown]
# ### **2.1 Handle null values** <font color = red>[2 marks]</font>

# %% [markdown]
# #### **2.1.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[1 Mark]</font>

# %%
# Check the number of missing values in each column
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# number_of_vehicles_involved       0
# property_damage                   0
# bodily_injuries                   0
# witnesses                         0
# police_report_available           0
# total_claim_amount                0
# injury_claim                      0
# property_claim                    0
# vehicle_claim                     0
# auto_make                         0
# auto_model                        0
# auto_year                         0
# fraud_reported                    0
# _c39                           1000
# dtype: int64

# %% [markdown]
# #### **2.1.2** Handle rows containing null values <font color="red">[1 Mark]</font>

# %%
# Handle the rows containing null values
df[df.isnull().any(axis=1)]
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0      250/500               1000                1406.91               0
# 1      250/500               2000                1197.22         5000000
# 2      100/300               2000                1413.14         5000000
# 3      250/500               2000                1415.74         6000000
# 4     500/1000               1000                1583.91         6000000
# ..         ...                ...                    ...             ...
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# 0         466132  ...                     YES              71610         6510
# 1         468176  ...                       ?               5070          780
# 2         430632  ...                      NO              34650         7700
# 3         608117  ...                      NO              63400         6340
# 4         610706  ...                      NO               6500         1300
# ..           ...  ...                     ...                ...          ...
# 995       431289  ...                       ?              87200        17440
# 996       608177  ...                       ?             108480        18080
# 997       442797  ...                     YES              67500         7500
# 998       441714  ...                     YES              46980         5220
# 999       612260  ...                       ?               5060          460
#
#     property_claim vehicle_claim   auto_make  auto_model auto_year  \
# 0            13020         52080        Saab         92x      2004
# 1              780          3510    Mercedes        E400      2007
# 2             3850         23100       Dodge         RAM      2007
# 3             6340         50720   Chevrolet       Tahoe      2014
# 4              650          4550      Accura         RSX      2009
# ..             ...           ...         ...         ...       ...
# 995           8720         61040       Honda      Accord      2006
# 996          18080         72320  Volkswagen      Passat      2015
# 997           7500         52500      Suburu     Impreza      1996
# 998           5220         36540        Audi          A5      1998
# 999            920          3680    Mercedes        E400      2007
#
#     fraud_reported _c39
# 0                Y  NaN
# 1                Y  NaN
# 2                N  NaN
# 3                Y  NaN
# 4                N  NaN
# ..             ...  ...
# 995              N  NaN
# 996              N  NaN
# 997              N  NaN
# 998              N  NaN
# 999              N  NaN
#
# [1000 rows x 40 columns]

# %%
## Above _c39 column has null values hence all the rows are being shown in above output

# %% [markdown]
# ### **2.2 Identify and handle redundant values and columns** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **2.2.1** Examine the columns to determine if any value or column needs to be treated <font color="red">[2 Mark]</font>

# %%
# Write code to display all the columns with their unique values and counts and check for redundant values
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].value_counts(dropna=False))
    print("-" * 50)
# Out:
# Column: months_as_customer
# months_as_customer
# 194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: count, Length: 391, dtype: int64
# --------------------------------------------------
# Column: age
# age
# 43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: count, dtype: int64
# --------------------------------------------------
# Column: policy_number
# policy_number
# 521585    1
# 687755    1
# 674485    1
# 223404    1
# 991480    1
#          ..
# 563878    1
# 620855    1
# 583169    1
# 337677    1
# 556080    1
# Name: count, Length: 1000, dtype: int64
# --------------------------------------------------
# Column: policy_bind_date
# policy_bind_date
# 2006-01-01    3
# 1992-04-28    3
# 1992-08-05    3
# 1991-12-14    2
# 2004-08-09    2
#              ..
# 2014-06-03    1
# 1998-12-12    1
# 1999-02-18    1
# 1997-10-30    1
# 1996-11-11    1
# Name: count, Length: 951, dtype: int64
# --------------------------------------------------
# Column: policy_state
# policy_state
# OH    352
# IL    338
# IN    310
# Name: count, dtype: int64
# --------------------------------------------------
# Column: policy_csl
# policy_csl
# 250/500     351
# 100/300     349
# 500/1000    300
# Name: count, dtype: int64
# --------------------------------------------------
# Column: policy_deductable
# policy_deductable
# 1000    351
# 500     342
# 2000    307
# Name: count, dtype: int64
# --------------------------------------------------
# Column: policy_annual_premium
# policy_annual_premium
# 1558.29    2
# 1215.36    2
# 1362.87    2
# 1073.83    2
# 1389.13    2
#           ..
# 1085.03    1
# 1437.33    1
# 988.29     1
# 1238.89    1
# 766.19     1
# Name: count, Length: 991, dtype: int64
# --------------------------------------------------
# Column: umbrella_limit
# umbrella_limit
#  0           798
#  6000000      57
#  5000000      46
#  4000000      39
#  7000000      29
#  3000000      12
#  8000000       8
#  9000000       5
#  2000000       3
#  10000000      2
# -1000000       1
# Name: count, dtype: int64
# --------------------------------------------------
# Column: insured_zip
# insured_zip
# 477695    2
# 469429    2
# 446895    2
# 431202    2
# 456602    2
#          ..
# 476303    1
# 450339    1
# 476502    1
# 600561    1
# 612260    1
# Name: count, Length: 995, dtype: int64
# --------------------------------------------------
# Column: insured_sex
# insured_sex
# FEMALE    537
# MALE      463
# Name: count, dtype: int64
# --------------------------------------------------
# Column: insured_education_level
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: count, dtype: int64
# --------------------------------------------------
# Column: insured_occupation
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: count, dtype: int64
# --------------------------------------------------
# Column: insured_hobbies
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: count, dtype: int64
# --------------------------------------------------
# Column: insured_relationship
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: count, dtype: int64
# --------------------------------------------------
# Column: capital-gains
# capital-gains
# 0        508
# 46300      5
# 51500      4
# 68500      4
# 55600      3
#         ...
# 36700      1
# 54900      1
# 69200      1
# 48800      1
# 50300      1
# Name: count, Length: 338, dtype: int64
# --------------------------------------------------
# Column: capital-loss
# capital-loss
#  0        475
# -31700      5
# -53700      5
# -50300      5
# -45300      4
#          ...
# -12100      1
# -17000      1
# -72900      1
# -19700      1
# -82100      1
# Name: count, Length: 354, dtype: int64
# --------------------------------------------------
# Column: incident_date
# incident_date
# 2015-02-02    28
# 2015-02-17    26
# 2015-01-07    25
# 2015-01-10    24
# 2015-02-04    24
# 2015-01-24    24
# 2015-01-19    23
# 2015-01-08    22
# 2015-01-13    21
# 2015-01-30    21
# 2015-02-12    20
# 2015-02-22    20
# 2015-01-31    20
# 2015-02-06    20
# 2015-02-21    19
# 2015-01-01    19
# 2015-02-23    19
# 2015-01-12    19
# 2015-01-14    19
# 2015-01-21    19
# 2015-01-03    18
# 2015-02-14    18
# 2015-02-01    18
# 2015-02-28    18
# 2015-01-20    18
# 2015-01-18    18
# 2015-02-25    18
# 2015-01-06    17
# 2015-01-09    17
# 2015-02-08    17
# 2015-02-24    17
# 2015-02-26    17
# 2015-02-13    16
# 2015-02-15    16
# 2015-02-16    16
# 2015-02-05    16
# 2015-01-16    16
# 2015-01-17    15
# 2015-02-18    15
# 2015-01-28    15
# 2015-01-15    15
# 2015-01-22    14
# 2015-02-20    14
# 2015-02-27    14
# 2015-01-23    13
# 2015-02-03    13
# 2015-01-27    13
# 2015-02-09    13
# 2015-01-04    12
# 2015-03-01    12
# 2015-01-26    11
# 2015-01-29    11
# 2015-01-02    11
# 2015-02-19    10
# 2015-02-11    10
# 2015-02-10    10
# 2015-02-07    10
# 2015-01-25    10
# 2015-01-11     9
# 2015-01-05     7
# Name: count, dtype: int64
# --------------------------------------------------
# Column: incident_type
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: count, dtype: int64
# --------------------------------------------------
# Column: collision_type
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# ?                  178
# Name: count, dtype: int64
# --------------------------------------------------
# Column: incident_severity
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: count, dtype: int64
# --------------------------------------------------
# Column: authorities_contacted
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# NaN           91
# Name: count, dtype: int64
# --------------------------------------------------
# Column: incident_state
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: count, dtype: int64
# --------------------------------------------------
# Column: incident_city
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: count, dtype: int64
# --------------------------------------------------
# Column: incident_location
# incident_location
# 9935 4th Drive         1
# 4214 MLK Ridge         1
# 8548 Cherokee Ridge    1
# 2352 MLK Drive         1
# 9734 2nd Ridge         1
#                       ..
# 6770 1st St            1
# 4119 Texas St          1
# 4347 2nd Ridge         1
# 1091 1st Drive         1
# 1416 Cherokee Ridge    1
# Name: count, Length: 1000, dtype: int64
# --------------------------------------------------
# Column: incident_hour_of_the_day
# incident_hour_of_the_day
# 17    54
# 3     53
# 0     52
# 23    51
# 16    49
# 13    46
# 10    46
# 4     46
# 6     44
# 9     43
# 14    43
# 21    42
# 18    41
# 12    40
# 19    40
# 7     40
# 15    39
# 22    38
# 8     36
# 20    34
# 5     33
# 2     31
# 11    30
# 1     29
# Name: count, dtype: int64
# --------------------------------------------------
# Column: number_of_vehicles_involved
# number_of_vehicles_involved
# 1    581
# 3    358
# 4     31
# 2     30
# Name: count, dtype: int64
# --------------------------------------------------
# Column: property_damage
# property_damage
# ?      360
# NO     338
# YES    302
# Name: count, dtype: int64
# --------------------------------------------------
# Column: bodily_injuries
# bodily_injuries
# 0    340
# 2    332
# 1    328
# Name: count, dtype: int64
# --------------------------------------------------
# Column: witnesses
# witnesses
# 1    258
# 2    250
# 0    249
# 3    243
# Name: count, dtype: int64
# --------------------------------------------------
# Column: police_report_available
# police_report_available
# ?      343
# NO     343
# YES    314
# Name: count, dtype: int64
# --------------------------------------------------
# Column: total_claim_amount
# total_claim_amount
# 59400    5
# 2640     4
# 70400    4
# 4320     4
# 44200    4
#         ..
# 65250    1
# 87100    1
# 6240     1
# 66600    1
# 67500    1
# Name: count, Length: 763, dtype: int64
# --------------------------------------------------
# Column: injury_claim
# injury_claim
# 0        25
# 640       7
# 480       7
# 660       5
# 580       5
#          ..
# 14840     1
# 6580      1
# 11820     1
# 16650     1
# 7500      1
# Name: count, Length: 638, dtype: int64
# --------------------------------------------------
# Column: property_claim
# property_claim
# 0        19
# 860       6
# 480       5
# 660       5
# 10000     5
#          ..
# 3590      1
# 6480      1
# 4580      1
# 4920      1
# 7500      1
# Name: count, Length: 626, dtype: int64
# --------------------------------------------------
# Column: vehicle_claim
# vehicle_claim
# 5040     7
# 3360     6
# 52080    5
# 4720     5
# 3600     5
#         ..
# 43360    1
# 25130    1
# 38940    1
# 47430    1
# 52500    1
# Name: count, Length: 726, dtype: int64
# --------------------------------------------------
# Column: auto_make
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: count, dtype: int64
# --------------------------------------------------
# Column: auto_model
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: count, dtype: int64
# --------------------------------------------------
# Column: auto_year
# auto_year
# 1995    56
# 1999    55
# 2005    54
# 2006    53
# 2011    53
# 2007    52
# 2003    51
# 2009    50
# 2010    50
# 2013    49
# 2002    49
# 2015    47
# 1997    46
# 2012    46
# 2008    45
# 2014    44
# 2001    42
# 2000    42
# 1998    40
# 2004    39
# 1996    37
# Name: count, dtype: int64
# --------------------------------------------------
# Column: fraud_reported
# fraud_reported
# N    753
# Y    247
# Name: count, dtype: int64
# --------------------------------------------------
# Column: _c39
# _c39
# NaN    1000
# Name: count, dtype: int64
# --------------------------------------------------

# %%
# Columns like collision_type, property_damage, and police_report_available contain ?, which likely represent missing values
df = df.replace("?", pd.NA)

df['collision_type'] = df['collision_type'].fillna('UNKNOWN')
df['property_damage'] = df['property_damage'].fillna('UNKNOWN')
df['police_report_available'] = df['police_report_available'].fillna('UNKNOWN')

# %%
df["collision_type"].value_counts()
# Out:
# collision_type
# Rear Collision     292
# Side Collision     276
# Front Collision    254
# UNKNOWN            178
# Name: count, dtype: int64

# %%
df.property_damage.value_counts()
# Out:
# property_damage
# UNKNOWN    360
# NO         338
# YES        302
# Name: count, dtype: int64

# %%
df.police_report_available.value_counts()
# Out:
# police_report_available
# UNKNOWN    343
# NO         343
# YES        314
# Name: count, dtype: int64

# %% [markdown]
# #### **2.2.2** Identify and drop any columns that are completely empty <font color="red">[1 Mark]</font>

# %%
# Identify and drop any columns that are completely empty
df.drop(columns=['_c39'], inplace=True)

# %% [markdown]
# #### **2.2.3** Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values <font color="red">[1 Mark]</font>

# %%
# Identify and drop rows where features have illogical or invalid values, such as negative values for features that should only have positive values
non_negative_columns = [
    'age', 'months_as_customer', 'policy_deductable', 'policy_annual_premium',
    'umbrella_limit', 'capital-gains',
    'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim',
    'number_of_vehicles_involved', 'bodily_injuries', 'witnesses'
]

# %%
invalid_rows = (df[non_negative_columns] < 0).any(axis=1)
invalid_rows.sum()
# Out:
# 1

# %%
df = df[~invalid_rows].copy()

# %% [markdown]
# #### **2.2.4** Identify and remove columns where a large proportion of the values are unique or near-unique, as these columns are likely to be identifiers or have very limited predictive power <font color="red">[1 Mark]</font>

# %%
# Identify and remove columns that are likely to be identifiers or have very limited predictive power
# Threshold: more than 95% unique values
threshold = 0.96

# Get number of rows
n_rows = len(df)

# Identify high-cardinality columns
high_card_cols = [col for col in df.columns if df[col].nunique() / n_rows > threshold]

# Display them
print("High-cardinality columns (likely identifiers):")
for col in high_card_cols:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# High-cardinality columns (likely identifiers):
# policy_number: 999 unique values
# policy_annual_premium: 990 unique values
# insured_zip: 994 unique values
# incident_location: 999 unique values

# %%
df = df.drop(columns=high_card_cols)

# %%
# Check the dataset
df.shape
# Out:
# (999, 35)

# %% [markdown]
# ### **2.3 Fix Data Types** <font color = red>[3 marks]</font>
# Carefully examine the dataset and identify columns that contain date or time information but are not stored as the appropriate data type. Convert these columns to the correct datetime data type to enable proper analysis and manipulation of temporal information.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_bind_date             999 non-null    object
#  3   policy_state                 999 non-null    object
#  4   policy_csl                   999 non-null    object
#  5   policy_deductable            999 non-null    int64
#  6   umbrella_limit               999 non-null    int64
#  7   insured_sex                  999 non-null    object
#  8   insured_education_level      999 non-null    object
#  9   insured_occupation           999 non-null    object
#  10  insured_hobbies              999 non-null    object
#  11  insured_relationship         999 non-null    object
#  12  capital-gains                999 non-null    int64
#  13  capital-loss                 999 non-null    int64
#  14  incident_date                999 non-null    object
#  15  incident_type                999 non-null    object
#  16  collision_type               999 non-null    object
#  17  incident_severity            999 non-null    object
#  18  authorities_contacted        908 non-null    object
#  19  incident_state               999 non-null    object
#  20  incident_city                999 non-null    object
#  21  incident_hour_of_the_day     999 non-null    int64
#  22  number_of_vehicles_involved  999 non-null    int64
#  23  property_damage              999 non-null    object
#  24  bodily_injuries              999 non-null    int64
#  25  witnesses                    999 non-null    int64
#  26  police_report_available      999 non-null    object
#  27  total_claim_amount           999 non-null    int64
#  28  injury_claim                 999 non-null    int64
#  29  property_claim               999 non-null    int64
#  30  vehicle_claim                999 non-null    int64
#  31  auto_make                    999 non-null    object
#  32  auto_model                   999 non-null    object
#  33  auto_year                    999 non-null    int64
#  34  fraud_reported               999 non-null    object
# dtypes: int64(15), object(20)
# memory usage: 281.0+ KB

# %%
# Fix the data types of the columns with incorrect data types
df['policy_bind_date'] = pd.to_datetime(df['policy_bind_date'], errors='coerce')
df['incident_date'] = pd.to_datetime(df['incident_date'], errors='coerce')

# %%
# Check the features of the data again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 999 entries, 0 to 999
# Data columns (total 35 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           999 non-null    int64
#  1   age                          999 non-null    int64
#  2   policy_bind_date             999 non-null    datetime64[ns]
#  3   policy_state                 999 non-null    object
#  4   policy_csl                   999 non-null    object
#  5   policy_deductable            999 non-null    int64
#  6   umbrella_limit               999 non-null    int64
#  7   insured_sex                  999 non-null    object
#  8   insured_education_level      999 non-null    object
#  9   insured_occupation           999 non-null    object
#  10  insured_hobbies              999 non-null    object
#  11  insured_relationship         999 non-null    object
#  12  capital-gains                999 non-null    int64
#  13  capital-loss                 999 non-null    int64
#  14  incident_date                999 non-null    datetime64[ns]
#  15  incident_type                999 non-null    object
#  16  collision_type               999 non-null    object
#  17  incident_severity            999 non-null    object
#  18  authorities_contacted        908 non-null    object
#  19  incident_state               999 non-null    object
#  20  incident_city                999 non-null    object
#  21  incident_hour_of_the_day     999 non-null    int64
#  22  number_of_vehicles_involved  999 non-null    int64
#  23  property_damage              999 non-null    object
#  24  bodily_injuries              999 non-null    int64
#  25  witnesses                    999 non-null    int64
#  26  police_report_available      999 non-null    object
#  27  total_claim_amount           999 non-null    int64
#  28  injury_claim                 999 non-null    int64
#  29  property_claim               999 non-null    int64
#  30  vehicle_claim                999 non-null    int64
#  31  auto_make                    999 non-null    object
#  32  auto_model                   999 non-null    object
#  33  auto_year                    999 non-null    int64
#  34  fraud_reported               999 non-null    object
# dtypes: datetime64[ns](2), int64(15), object(18)
# memory usage: 281.0+ KB

# %% [markdown]
# ## **3. Train-Validation Split** <font color = red>[5 marks]</font>

# %% [markdown]
# ### **3.1 Import required libraries**

# %%
# Import train-test-split
# !pip install scikit-learn

from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: scikit-learn in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from scikit-learn) (3.6.0)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Vedan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### **3.2 Define feature and target variables** <font color = red>[2 Marks]</font>

# %%
# Put the target variable in y
y = df['fraud_reported']

# Put all the feature variables in X
X = df.drop(columns=['fraud_reported'])

# %%
X.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_bind_date', 'policy_state',
#        'policy_csl', 'policy_deductable', 'umbrella_limit', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'number_of_vehicles_involved',
#        'property_damage', 'bodily_injuries', 'witnesses',
#        'police_report_available', 'total_claim_amount', 'injury_claim',
#        'property_claim', 'vehicle_claim', 'auto_make', 'auto_model',
#        'auto_year'],
#       dtype='object')

# %% [markdown]
# ### **3.3 Split the data** <font color="red">[3 Marks]</font>

# %%
# Split the dataset into 70% train and 30% validation and use stratification on the target variable

X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.3, 
    stratify=y, 
    random_state=42
)

# Reset index for all train and test sets

X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)


print(f"Training set: {X_train.shape}, Validation set: {X_test.shape}")
# Out:
# Training set: (699, 34), Validation set: (300, 34)

# %% [markdown]
# ## **4. EDA on training data** <font color = red>[20 marks]</font>

# %% [markdown]
# ### **4.1 Perform univariate analysis** <font color = red>[5 marks]</font>

# %% [markdown]
# #### **4.1.1** Identify and select numerical columns from training data for univariate analysis <font color = "red">[1 Mark]</font>

# %%
# Select numerical columns
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Display the list of numerical columns
print("Numerical columns in training data:")
print(numerical_cols)
# Out:
# Numerical columns in training data:
# ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']

# %% [markdown]
# #### **4.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics <font color = "red">[4 Marks]</font>

# %%
# Plot all the numerical columns to understand their distribution
sns.set(style="whitegrid")
plt.figure(figsize=(16, 30))

# Loop through numerical columns and plot histograms
for idx, col in enumerate(numerical_cols):
    plt.subplot(len(numerical_cols) // 2 + 1, 2, idx + 1)
    sns.histplot(X_train[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **4.2 Perform correlation analysis** <font color="red">[3 Marks]</font>

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

corr_matrix = X_train[numerical_cols].corr()

# Set plot size and style
plt.figure(figsize=(14, 10))
sns.set(style="white")

# Plot Heatmap of the correlation matrix
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True,
            linewidths=0.5, cbar_kws={"shrink": 0.7})

plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %%
## We see high corelation below features
        # age and Months_as_customer
        # total_claim_amount with injury_claim
        # total_claim_amount with property_claim
        # total_claim_amount with vehicle_claim

# %% [markdown]
# ### **4.3 Check class balance** <font color="red">[2 Marks]</font>

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances using visualisation for better understanding.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6, 4))
sns.countplot(x=y_train, palette='Set2')

# Add counts on top of bars
total = len(y)
for p in plt.gca().patches:
    count = int(p.get_height())
    percent = f"{100 * count / total:.1f}%"
    plt.text(p.get_x() + p.get_width() / 2., count + 5, percent, ha="center")

plt.title("Distribution of Fraud vs Non-Fraud")
plt.xlabel("Fraud Reported (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### **4.4 Perform bivariate analysis** <font color="red">[10 Marks]</font>

# %% [markdown]
# #### **4.4.1** Target likelihood analysis for categorical variables. <font color="red">[5 Marks]</font>
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
y_train = y_train.map({'Y': 1, 'N': 0}) if y_train.dtype == 'object' else y_train

# %%
def target_likelihood_analysis_split(X, y, dataset_name='Train'):
    df = X.copy()
    df['fraud_reported'] = y
    
    categorical_cols = df.select_dtypes(include='object').columns.tolist()
    
    for col in categorical_cols:
        likelihood_df = df.groupby(col)['fraud_reported'].agg(['mean', 'count']).sort_values(by='mean', ascending=False)
        
        print(f"\n🔍 {dataset_name} Set - Feature: {col}")
        print(likelihood_df)

        # Plot the likelihood
        plt.figure(figsize=(10, 4))
        sns.barplot(x=likelihood_df['mean'], y=likelihood_df.index, palette='viridis')
        plt.title(f"{dataset_name} Set: Fraud Likelihood by {col}")
        plt.xlabel("Fraud Likelihood (mean of fraud_reported)")
        plt.ylabel(col)
        plt.grid(axis='x', linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()

# %%
target_likelihood_analysis_split(X_train, y_train, 'Train')
# Out:
# 🔍 Train Set - Feature: policy_state
#                   mean  count
# policy_state
# OH            0.253112    241
# IN            0.245455    220
# IL            0.243697    238
# 🔍 Train Set - Feature: policy_csl
#                 mean  count
# policy_csl
# 100/300     0.268000    250
# 250/500     0.251064    235
# 500/1000    0.219626    214
# 🔍 Train Set - Feature: insured_sex
#                  mean  count
# insured_sex
# FEMALE       0.249330    373
# MALE         0.245399    326
# 🔍 Train Set - Feature: insured_education_level
#                              mean  count
# insured_education_level
# JD                       0.283186    113
# MD                       0.263158     95
# Masters                  0.252525     99
# College                  0.246914     81
# PhD                      0.244444     90
# Associate                0.234234    111
# High School              0.209091    110
# 🔍 Train Set - Feature: insured_occupation
#                         mean  count
# insured_occupation
# transport-moving    0.344828     58
# exec-managerial     0.339286     56
# craft-repair        0.301887     53
# farming-fishing     0.281250     32
# sales               0.272727     55
# armed-forces        0.260870     46
# tech-support        0.259259     54
# machine-op-inspct   0.246154     65
# protective-serv     0.243243     37
# prof-specialty      0.190476     63
# other-service       0.187500     48
# priv-house-serv     0.180000     50
# adm-clerical        0.170213     47
# handlers-cleaners   0.142857     35
# 🔍 Train Set - Feature: insured_hobbies
#                      mean  count
# insured_hobbies
# chess            0.906250     32
# cross-fit        0.760000     25
# polo             0.312500     32
# yachting         0.297297     37
# paintball        0.255319     47
# hiking           0.250000     36
# base-jumping     0.236842     38
# video-games      0.235294     34
# reading          0.224490     49
# skydiving        0.222222     36
# board-games      0.218750     32
# sleeping         0.208333     24
# bungie-jumping   0.175000     40
# exercise         0.153846     39
# movies           0.151515     33
# dancing          0.117647     34
# basketball       0.111111     18
# kayaking         0.111111     36
# camping          0.108108     37
# golf             0.075000     40
# 🔍 Train Set - Feature: insured_relationship
#                           mean  count
# insured_relationship
# other-relative        0.299213    127
# unmarried             0.294118    102
# wife                  0.271930    114
# not-in-family         0.239669    121
# husband               0.210526    114
# own-child             0.173554    121
# 🔍 Train Set - Feature: incident_type
#                               mean  count
# incident_type
# Single Vehicle Collision  0.287234    282
# Multi-vehicle Collision   0.278351    291
# Parked Car                0.092308     65
# Vehicle Theft             0.081967     61
# 🔍 Train Set - Feature: collision_type
#                      mean  count
# collision_type
# Rear Collision   0.297170    212
# Front Collision  0.289017    173
# Side Collision   0.260638    188
# UNKNOWN          0.087302    126
# 🔍 Train Set - Feature: incident_severity
#                        mean  count
# incident_severity
# Major Damage       0.609375    192
# Total Loss         0.150259    193
# Minor Damage       0.090909    253
# Trivial Damage     0.065574     61
# 🔍 Train Set - Feature: authorities_contacted
#                            mean  count
# authorities_contacted
# Ambulance              0.316176    136
# Other                  0.285714    140
# Fire                   0.280255    157
# Police                 0.202020    198
# 🔍 Train Set - Feature: incident_state
#                     mean  count
# incident_state
# OH              0.421053     19
# PA              0.315789     19
# NC              0.313253     83
# SC              0.299435    177
# VA              0.266667     75
# NY              0.212644    174
# WV              0.151316    152
# 🔍 Train Set - Feature: incident_city
#                    mean  count
# incident_city
# Arlington      0.298077    104
# Springfield    0.276190    105
# Columbus       0.272727    110
# Hillsdale      0.250000     92
# Northbrook     0.213483     89
# Riverwood      0.212121     99
# Northbend      0.200000    100
# 🔍 Train Set - Feature: property_damage
#                      mean  count
# property_damage
# UNKNOWN          0.290323    248
# YES              0.280193    207
# NO               0.176230    244
# 🔍 Train Set - Feature: police_report_available
#                              mean  count
# police_report_available
# NO                       0.255144    243
# UNKNOWN                  0.255061    247
# YES                      0.229665    209
# 🔍 Train Set - Feature: auto_make
#                 mean  count
# auto_make
# Audi        0.326923     52
# Ford        0.296296     54
# Mercedes    0.294118     51
# Honda       0.290323     31
# BMW         0.280000     50
# Volkswagen  0.275000     40
# Chevrolet   0.272727     55
# Jeep        0.250000     44
# Suburu      0.238095     63
# Saab        0.235294     51
# Toyota      0.234043     47
# Dodge       0.188679     53
# Nissan      0.172414     58
# Accura      0.140000     50
# 🔍 Train Set - Feature: auto_model
#                     mean  count
# auto_model
# X6              0.500000     10
# Civic           0.500000     12
# Silverado       0.437500     16
# Tahoe           0.400000     20
# Maxima          0.375000     16
# Grand Cherokee  0.375000     16
# A5              0.375000     24
# F150            0.363636     22
# C300            0.333333     12
# Forrestor       0.333333     24
# 93              0.307692     13
# M5              0.300000     10
# X5              0.294118     17
# E400            0.291667     24
# A3              0.285714     28
# Jetta           0.285714     21
# Highlander      0.277778     18
# ML350           0.266667     15
# Fusion          0.266667     15
# 92x             0.263158     19
# Passat          0.263158     19
# Escape          0.235294     17
# Camry           0.235294     17
# Impreza         0.214286     14
# Accord          0.200000     10
# Neon            0.192308     26
# RAM             0.185185     27
# Wrangler        0.178571     28
# MDX             0.172414     29
# Corolla         0.166667     12
# Legacy          0.160000     25
# 95              0.157895     19
# Ultima          0.150000     20
# CRV             0.111111      9
# TL              0.100000     10
# RSX             0.090909     11
# 3 Series        0.076923     13
# Pathfinder      0.045455     22
# Malibu          0.000000     19

# %% [markdown]
# #### **4.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome using appropriate visualisation techniques to identify trends and potential interactions. <font color="red">[5 Marks]</font>

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
def plot_numerical_vs_target(X, y, dataset_name='Train'):
    df = X.copy()
    df['fraud_reported'] = y
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

    print(f"\n🔍 Visualizing for {dataset_name} set")

    for col in numerical_cols:
        plt.figure(figsize=(8, 4))
        sns.boxplot(x='fraud_reported', y=col, data=df, palette='Set2')
        plt.title(f"{dataset_name} Set: {col} vs Fraud Reported")
        plt.xlabel("Fraud Reported (0 = No, 1 = Yes)")
        plt.ylabel(col)
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()

# %%
plot_numerical_vs_target(X_train, y_train, 'Train')
# Out:
# 🔍 Visualizing for Train set

# %% [markdown]
# ## **5. EDA on validation data** <font color = red>[OPTIONAL]</font>

# %% [markdown]
# ### **5.1 Perform univariate analysis**

# %% [markdown]
# #### **5.1.1** Identify and select numerical columns from training data for univariate analysis.

# %%
# Select numerical columns
numerical_cols_test = X_test.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Display the list of numerical columns
print("Numerical columns in training data:")
print(numerical_cols_test)
# Out:
# Numerical columns in training data:
# ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year']

# %% [markdown]
# #### **5.1.2** Visualise the distribution of selected numerical features using appropriate plots to understand their characteristics.

# %%
# Plot all the numerical columns to understand their distribution
sns.set(style="whitegrid")
plt.figure(figsize=(16, 30))

# Loop through numerical columns and plot histograms
for idx, col in enumerate(numerical_cols_test):
    plt.subplot(len(numerical_cols_test) // 2 + 1, 2, idx + 1)
    sns.histplot(X_test[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **5.2 Perform correlation analysis**

# %% [markdown]
#  Investigate the relationships between numerical features to identify potential multicollinearity or dependencies. Visualise the correlation structure using an appropriate method to gain insights into feature relationships.

# %%
# Create correlation matrix for numerical columns

corr_matrix_test = X_test[numerical_cols_test].corr()

# Set plot size and style
plt.figure(figsize=(14, 10))
sns.set(style="white")

# Plot Heatmap of the correlation matrix
sns.heatmap(corr_matrix_test, annot=True, cmap='coolwarm', fmt=".2f", square=True,
            linewidths=0.5, cbar_kws={"shrink": 0.7})

plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# ### **5.3 Check class balance**

# %% [markdown]
# Examine the distribution of the target variable to identify potential class imbalances. Visualise the distribution for better understanding.

# %%
# Plot a bar chart to check class balance
plt.figure(figsize=(6, 4))
sns.countplot(x=y_test, palette='Set2')

# Add counts on top of bars
total = len(y)
for p in plt.gca().patches:
    count = int(p.get_height())
    percent = f"{100 * count / total:.1f}%"
    plt.text(p.get_x() + p.get_width() / 2., count + 5, percent, ha="center")

plt.title("Distribution of Fraud vs Non-Fraud")
plt.xlabel("Fraud Reported (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### **5.4 Perform bivariate analysis**

# %% [markdown]
# #### **5.4.1** Target likelihood analysis for categorical variables.
# Investigate the relationships between categorical features and the target variable by analysing the target event likelihood (for the `'Y'` event) for each level of every relevant categorical feature. Through this analysis, identify categorical features that do not contribute much in explaining the variation in the target variable.

# %%
# Write a function to calculate and analyse the target variable likelihood for categorical features
y_test = y_test.map({'Y': 1, 'N': 0}) if y_test.dtype == 'object' else y_test

## FUnction is already written above so just calling same function with test data

target_likelihood_analysis_split(X_test, y_test, 'Validation')
# Out:
# 🔍 Validation Set - Feature: policy_state
#                   mean  count
# policy_state
# IN            0.277778     90
# OH            0.272727    110
# IL            0.190000    100
# 🔍 Validation Set - Feature: policy_csl
#                 mean  count
# policy_csl
# 250/500     0.284483    116
# 100/300     0.234694     98
# 500/1000    0.209302     86
# 🔍 Validation Set - Feature: insured_sex
#                  mean  count
# insured_sex
# MALE         0.301471    136
# FEMALE       0.201220    164
# 🔍 Validation Set - Feature: insured_education_level
#                              mean  count
# insured_education_level
# PhD                      0.314286     35
# College                  0.292683     41
# MD                       0.265306     49
# High School              0.260000     50
# Associate                0.242424     33
# JD                       0.208333     48
# Masters                  0.159091     44
# 🔍 Validation Set - Feature: insured_occupation
#                         mean  count
# insured_occupation
# exec-managerial     0.450000     20
# farming-fishing     0.333333     21
# tech-support        0.333333     24
# handlers-cleaners   0.315789     19
# craft-repair        0.285714     21
# sales               0.285714     21
# prof-specialty      0.272727     22
# machine-op-inspct   0.222222     27
# armed-forces        0.217391     23
# protective-serv     0.192308     26
# adm-clerical        0.166667     18
# priv-house-serv     0.142857     21
# other-service       0.130435     23
# transport-moving    0.071429     14
# 🔍 Validation Set - Feature: insured_hobbies
#                      mean  count
# insured_hobbies
# cross-fit        0.700000     10
# chess            0.642857     14
# board-games      0.437500     16
# reading          0.400000     15
# base-jumping     0.363636     11
# yachting         0.312500     16
# exercise         0.277778     18
# basketball       0.250000     16
# skydiving        0.230769     13
# golf             0.200000     15
# polo             0.200000     15
# hiking           0.187500     16
# movies           0.181818     22
# sleeping         0.176471     17
# bungie-jumping   0.125000     16
# video-games      0.125000     16
# dancing          0.111111      9
# paintball        0.100000     10
# kayaking         0.058824     17
# camping          0.055556     18
# 🔍 Validation Set - Feature: insured_relationship
#                           mean  count
# insured_relationship
# not-in-family         0.301887     53
# own-child             0.290323     62
# other-relative        0.280000     50
# wife                  0.275000     40
# husband               0.196429     56
# unmarried             0.102564     39
# 🔍 Validation Set - Feature: incident_type
#                               mean  count
# incident_type
# Single Vehicle Collision  0.300000    120
# Multi-vehicle Collision   0.257812    128
# Parked Car                0.105263     19
# Vehicle Theft             0.090909     33
# 🔍 Validation Set - Feature: collision_type
#                      mean  count
# collision_type
# Rear Collision   0.350000     80
# Front Collision  0.246914     81
# Side Collision   0.241379     87
# UNKNOWN          0.096154     52
# 🔍 Validation Set - Feature: incident_severity
#                        mean  count
# incident_severity
# Major Damage       0.602410     83
# Minor Damage       0.148515    101
# Total Loss         0.080460     87
# Trivial Damage     0.068966     29
# 🔍 Validation Set - Feature: authorities_contacted
#                            mean  count
# authorities_contacted
# Other                  0.396552     58
# Fire                   0.242424     66
# Ambulance              0.237288     59
# Police                 0.223404     94
# 🔍 Validation Set - Feature: incident_state
#                     mean  count
# incident_state
# OH              0.500000      4
# NC              0.307692     26
# SC              0.281690     71
# WV              0.246154     65
# NY              0.238636     88
# PA              0.181818     11
# VA              0.142857     35
# 🔍 Validation Set - Feature: incident_city
#                    mean  count
# incident_city
# Northbend      0.311111     45
# Arlington      0.276596     47
# Riverwood      0.257143     35
# Hillsdale      0.244898     49
# Northbrook     0.242424     33
# Columbus       0.230769     39
# Springfield    0.173077     52
# 🔍 Validation Set - Feature: property_damage
#                      mean  count
# property_damage
# UNKNOWN          0.276786    112
# NO               0.244681     94
# YES              0.212766     94
# 🔍 Validation Set - Feature: police_report_available
#                              mean  count
# police_report_available
# UNKNOWN                  0.273684     95
# NO                       0.240000    100
# YES                      0.228571    105
# 🔍 Validation Set - Feature: auto_make
#                 mean  count
# auto_make
# Mercedes    0.500000     14
# Dodge       0.370370     27
# Accura      0.333333     18
# Ford        0.333333     18
# Chevrolet   0.300000     20
# Volkswagen  0.285714     28
# BMW         0.272727     22
# Audi        0.235294     17
# Suburu      0.235294     17
# Honda       0.208333     24
# Saab        0.206897     29
# Nissan      0.200000     20
# Toyota      0.086957     23
# Jeep        0.000000     23
# 🔍 Validation Set - Feature: auto_model
#                     mean  count
# auto_model
# ML350           0.800000      5
# RAM             0.562500     16
# Impreza         0.500000      6
# C300            0.500000      6
# MDX             0.428571      7
# F150            0.400000      5
# M5              0.400000      5
# X5              0.333333      6
# Silverado       0.333333      6
# Pathfinder      0.333333      9
# 92x             0.333333      9
# Fusion          0.333333      6
# X6              0.333333      6
# Accord          0.333333      3
# TL              0.300000     10
# Malibu          0.300000     10
# Escape          0.285714      7
# Passat          0.285714     14
# Jetta           0.285714     14
# Tahoe           0.250000      4
# 95              0.250000      8
# Highlander      0.250000      4
# A5              0.250000      8
# A3              0.222222      9
# Civic           0.200000     10
# CRV             0.181818     11
# Legacy          0.142857      7
# Maxima          0.125000      8
# Corolla         0.125000      8
# Neon            0.090909     11
# 93              0.083333     12
# E400            0.000000      3
# Camry           0.000000     11
# RSX             0.000000      1
# Grand Cherokee  0.000000      9
# Forrestor       0.000000      4
# Ultima          0.000000      3
# Wrangler        0.000000     14
# 3 Series        0.000000      5

# %% [markdown]
# #### **5.4.2** Explore the relationships between numerical features and the target variable to understand their impact on the target outcome. Utilise appropriate visualisation techniques to identify trends and potential interactions.

# %%
# Visualise the relationship between numerical features and the target variable to understand their impact on the target outcome
## Function is already written above hence calling the function with test data

plot_numerical_vs_target(X_test, y_test, 'Validation')
# Out:
# 🔍 Visualizing for Validation set

# %% [markdown]
# ## **6. Feature Engineering** <font color = red>[25 marks]</font>

# %% [markdown]
# ### **6.1 Perform resampling** <font color="red">[3 Marks]</font>

# %% [markdown]
# Handle class imbalance in the training data by applying resampling technique.
#
# Use the **RandomOverSampler** technique to balance the data and handle class imbalance. This method increases the number of samples in the minority class by randomly duplicating them, creating synthetic data points with similar characteristics. This helps prevent the model from being biased toward the majority class and improves its ability to predict the minority class more accurately.
#
# **Note:** You can try other resampling techniques to handle class imbalance

# %%
# Import RandomOverSampler from imblearn library


#!pip install numpy==1.23.5 scipy==1.9.3 scikit-learn==1.2.2 imbalanced-learn==0.10.1

from imblearn.over_sampling import RandomOverSampler
print("Import successful!")

# Perform resampling on training data

ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# Check class distribution
y_train_resampled.value_counts()
# Out:
# Import successful!
# fraud_reported
# 0    526
# 1    526
# Name: count, dtype: int64

# %% [markdown]
# ### **6.2 Feature Creation** <font color="red">[4 marks]</font>

# %% [markdown]
# Create new features from existing ones to enhance the model's ability to capture patterns in the data. This may involve deriving features from date/time columns, combining features, or creating interaction terms.

# %%
# Create new features based on your understanding for both training and validation data

from sklearn.model_selection import train_test_split

# Assuming `X` contains all features and `y` is the target
X_train, X_validation, y_train, y_validation = train_test_split(
    X, y, test_size=0.3, stratify=y, random_state=42
)

# Create a new feature:claim amount per vehicle age
X_train_resampled["claim_per_vehicle_age"] = X_train_resampled["total_claim_amount"] / (X_train_resampled["age"] + 1)

# Apply the same to validation set
X_validation["claim_per_vehicle_age"] = X_validation["total_claim_amount"] / (X_validation["age"] + 1)

# %% [markdown]
# ### **6.3 Handle redundant columns** <font color="red">[3 marks]</font>

# %% [markdown]
# Analyse the data to identify features that may be redundant or contribute minimal information toward predicting the target variable and drop them.
#
# - You can consider features that exhibit high correlation with other variables, which you may have observed during the EDA phase.
# - Features that don't strongly influence the prediction, which you may have observed during the EDA phase.
# - Categorical columns with low value counts for some levels can be remapped to reduce number of unique levels, and features with very high counts for just one level may be removed, as they resemble unique identifier columns and do not provide substantial predictive value.
# - Additionally, eliminate any columns from which the necessary features have already been extracted in the preceding step.

# %%
# Drop redundant columns from training and validation data
columns_to_drop = ["policy_number", "incident_location", "auto_make", "_c39"]

columns_to_drop_actual = [col for col in columns_to_drop if col in X_train_resampled.columns]

X_train_resampled.drop(columns=columns_to_drop_actual, inplace=True)
X_validation.drop(columns=columns_to_drop_actual, inplace=True)

# %%
# Check the data
print("Columns in X_train_resampled:")
print(X_train_resampled.columns.tolist())

print("\nColumns in X_validation:")
print(X_validation.columns.tolist())

#Check shape of data frame

print(f"X_train_resampled shape: {X_train_resampled.shape}")
print(f"X_validation shape: {X_validation.shape}")

#Check any missing values

print("Missing values in training set:")
print(X_train_resampled.isnull().sum().sort_values(ascending=False).head())

print("\nMissing values in validation set:")
print(X_validation.isnull().sum().sort_values(ascending=False).head())
# Out:
# Columns in X_train_resampled:
# ['months_as_customer', 'age', 'policy_bind_date', 'policy_state', 'policy_csl', 'policy_deductable', 'umbrella_limit', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'capital-gains', 'capital-loss', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'property_damage', 'bodily_injuries', 'witnesses', 'police_report_available', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_model', 'auto_year', 'claim_per_vehicle_age']
#
# Columns in X_validation:
# ['months_as_customer', 'age', 'policy_bind_date', 'policy_state', 'policy_csl', 'policy_deductable', 'umbrella_limit', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'capital-gains', 'capital-loss', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'property_damage', 'bodily_injuries', 'witnesses', 'police_report_available', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_model', 'auto_year', 'claim_per_vehicle_age']
# X_train_resampled shape: (1052, 34)
# X_validation shape: (300, 34)
# Missing values in training set:
# authorities_contacted       82
# witnesses                    0
# incident_state               0
# incident_city                0
# incident_hour_of_the_day     0
# dtype: int64
#
# Missing values in validation set:
# authorities_contacted       23
# witnesses                    0
# incident_state               0
# incident_city                0
# incident_hour_of_the_day     0
# dtype: int64

# %% [markdown]
# ### **6.4 Combine values in Categorical Columns** <font color="red">[6 Marks]</font>
# During the EDA process, categorical columns with multiple unique values may be identified. To enhance model performance, it is essential to refine these categorical features by grouping values that have low frequency or provide limited predictive information.
#
# Combine categories that occur infrequently or exhibit similar behavior to reduce sparsity and improve model generalisation.

# %%
# Combine categories that have low frequency or provide limited predictive information

def combine_rare_categories(df, column, threshold=0.05):
    freq = df[column].value_counts(normalize=True)
    rare_labels = freq[freq < threshold].index
    df[column] = df[column].apply(lambda x: 'Other' if x in rare_labels else x)
    return df

for col in ['insured_education_level', 'incident_type', 'incident_severity']:
    X_train_resampled = combine_rare_categories(X_train_resampled, col)
    X_validation = combine_rare_categories(X_validation, col)

# %% [markdown]
# ### **6.5 Dummy variable creation** <font color="red">[6 Marks]</font>
# Transform categorical variables into numerical representations using dummy variables. Ensure consistent encoding between training and validation data.

# %% [markdown]
# #### **6.5.1** Identify categorical columns for dummy variable creation <font color="red">[1 Mark]</font>

# %%
# Identify the categorical columns for creating dummy variables

categorical_cols = X_train_resampled.select_dtypes(include='object').columns.tolist()

# %% [markdown]
# #### **6.5.2** Create dummy variables for categorical columns in training data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in training data

X_train_resampled = pd.get_dummies(X_train_resampled, columns=categorical_cols, drop_first=True)
X_validation = pd.get_dummies(X_validation, columns=categorical_cols, drop_first=True)

# %% [markdown]
# #### **6.5.3** Create dummy variables for categorical columns in validation data <font color="red">[2 Marks]</font>

# %%
# Create dummy variables using the 'get_dummies' for categorical columns in validation data

X_train_resampled, X_validation = X_train_resampled.align(X_validation, join='left', axis=1, fill_value=0)

# %% [markdown]
# #### **6.5.4** Create dummy variable for dependent feature in training and validation data <font color = "red">[1 Mark]</font>

# %%
# Create dummy variable for dependent feature in training data

# Create dummy variable for dependent feature in validation data

# %% [markdown]
# ### **6.6 Feature scaling** <font color = red>[3 marks]</font>
# Scale numerical features to a common range to prevent features with larger values from dominating the model.  Choose a scaling method appropriate for the data and the chosen model. Apply the same scaling to both training and validation data.

# %%
# Import the necessary scaling tool from scikit-learn
from sklearn.preprocessing import StandardScaler

# Scale the numeric features present in the training data

scaler = StandardScaler()
# Scale the numeric features present in the validation data

numerical_cols = X_train_resampled.select_dtypes(include=['int64', 'float64']).columns

X_train_resampled[numerical_cols] = scaler.fit_transform(X_train_resampled[numerical_cols])
X_validation[numerical_cols] = scaler.transform(X_validation[numerical_cols])

# %% [markdown]
# ## **7. Model Building** <font color = red>[50 marks]</font>

# %% [markdown]
# In this task, you will be building two machine learning models: Logistic Regression and Random Forest. Each model will go through a structured process to ensure optimal performance. The key steps for each model are outlined below:
#
# **Logistic Regression Model**
# - Feature Selection using RFECV – Identify the most relevant features using Recursive Feature Elimination with Cross-Validation.
# - Model Building and Multicollinearity Assessment – Build the logistic regression model and analyse statistical aspects such as p-values and VIFs to detect multicollinearity.
# - Model Training and Evaluation on Training Data – Fit the model on the training data and assess initial performance.
# - Finding the Optimal Cutoff – Determine the best probability threshold by analysing the sensitivity-specificity tradeoff and precision-recall tradeoff.
# - FInal Prediction and Evaluation on Training Data using the Optimal Cutoff – Generate final predictions using the selected cutoff and evaluate model performance.
#
# **Random Forest Model**
# - Get Feature Importances - Obtain the importance scores for each feature and select the important features to train the model.
# - Model Evaluation on Training Data – Assess performance metrics on the training data.
# - Check Model Overfitting using Cross-Validation – Evaluate generalisation by performing cross-validation.
# - Hyperparameter Tuning using Grid Search – Optimise model performance by fine-tuning hyperparameters.
# - Final Model and Evaluation on Training Data – Train the final model using the best parameters and assess its performance.

# %% [markdown]
# ### **7.1 Feature selection** <font color = red>[4 marks]</font>
# Identify and select the most relevant features for building a logistic regression model using Recursive Feature Elimination with Cross-Validation (RFECV).

# %% [markdown]
# #### **7.1.1** Import necessary libraries <font color="red">[1 Mark]</font>

# %%
# Import necessary libraries
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt

# %% [markdown]
# #### **7.1.2** Perform feature selection <font color="red">[2 Mark]</font>

# %%
# Initialize logistic regression model
lr = LogisticRegression(max_iter=1000, random_state=42)


# Drop datetime columns from train (and optionally from validation later)
datetime_cols = X_train_resampled.select_dtypes(include=["datetime64"]).columns.tolist()
X_train_rfecv = X_train_resampled.drop(columns=datetime_cols)


# Set up cross-validation and model
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
lr = LogisticRegression(max_iter=1000, random_state=42)


# Apply RFECV to identify the most relevant features
selector = RFECV(estimator=lr, step=1, cv=cv, scoring='accuracy', n_jobs=-1)
selector.fit(X_train_rfecv, y_train_resampled)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#       estimator=LogisticRegression(max_iter=1000, random_state=42), n_jobs=-1,
#       scoring='accuracy')

# %%
# Display the features ranking by RFECV in a DataFrame
selected_features = X_train_rfecv.columns[selector.support_]
print("✅ RFECV Selected Features:")
print(selected_features.tolist())
# Out:
# ✅ RFECV Selected Features:
# ['insured_hobbies_chess', 'insured_hobbies_cross-fit', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage']

# %% [markdown]
# #### **7.1.2** Retain the selected features <font color="red">[1 Mark]</font>

# %%
# Put columns selected by RFECV into variable 'col'
col = X_train_rfecv.columns[selector.support_].tolist()
print(col)
# Out:
# ['insured_hobbies_chess', 'insured_hobbies_cross-fit', 'incident_severity_Minor Damage', 'incident_severity_Total Loss', 'incident_severity_Trivial Damage']

# %% [markdown]
# ### **7.2 Build Logistic Regression Model** <font color = red>[12 marks]</font>
# After selecting the optimal features using RFECV, utilise these features to build a logistic regression model with Statsmodels. This approach enables a detailed statistical analysis of the model, including the assessment of p-values and Variance Inflation Factors (VIFs). Evaluating these metrics is crucial for detecting multicollinearity and ensuring that the selected predictors are not highly correlated.

# %% [markdown]
# #### **7.2.1** Select relevant features and add constant in training data <font color="red">[1 Mark]</font>

# %%
# Select only the columns selected by RFECV

# Create new datasets with selected features only
X_train_stats = X_train_rfecv[col]
X_validation_stats = X_validation[col]  # Optional: for later prediction

# %%
# Import statsmodels and add constant
# !pip install statsmodels
import statsmodels.api as sm

# Add a constant term (intercept) to the model
X_train_stats_const = sm.add_constant(X_train_stats)
# Check the data
print("Shape of X_train_stats_const:", X_train_stats_const.shape)
print("Preview of training data with constant column:")
display(X_train_stats_const.head())

print("\nTarget variable (y_train_resampled):")
print(y_train_resampled.value_counts())
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.5-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from statsmodels) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vedan\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.5-cp311-cp311-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB 660.6 kB/s eta 0:00:15
#    --- ------------------------------------ 0.7/9.6 MB 7.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.0/9.6 MB 14.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.2/9.6 MB 17.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.6 MB 19.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.6 MB 21.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.0/9.6 MB 21.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 22.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.6 MB 22.2 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 15.0 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/232.9 kB ? eta -:--:--
#    --------------------------------------- 232.9/232.9 kB 13.9 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.5
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\Vedan\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Shape of X_train_stats_const: (1052, 6)
# Preview of training data with constant column:
#    const  insured_hobbies_chess  insured_hobbies_cross-fit  \
# 0    1.0                  False                      False
# 1    1.0                  False                      False
# 2    1.0                  False                      False
# 3    1.0                  False                      False
# 4    1.0                  False                      False
#
#    incident_severity_Minor Damage  incident_severity_Total Loss  \
# 0                           False                         False
# 1                           False                          True
# 2                           False                         False
# 3                            True                         False
# 4                           False                          True
#
#    incident_severity_Trivial Damage
# 0                             False
# 1                             False
# 2                              True
# 3                             False
# 4                             False
# Target variable (y_train_resampled):
# fraud_reported
# 0    526
# 1    526
# Name: count, dtype: int64

# %% [markdown]
# #### **7.2.2** Fit logistic regression model <font color="red">[2 Marks]</font>

# %%
# Fit a logistic Regression model on X_train after adding a constant and output the summary

# Convert all bool columns to integers
X_train_stats_const = X_train_stats_const.astype({col: 'int' for col in X_train_stats_const.select_dtypes('bool').columns})

# Double-check the dtypes again
print(X_train_stats_const.dtypes)

#Fit the model
logit_model = sm.Logit(y_train_filtered, X_train_stats_const)
result = logit_model.fit()
print(result.summary())
# Out:
# const                               float64
# insured_hobbies_chess                 int32
# insured_hobbies_cross-fit             int32
# incident_severity_Minor Damage        int32
# incident_severity_Total Loss          int32
# incident_severity_Trivial Damage      int32
# dtype: object
# Optimization terminated successfully.
#          Current function value: 0.377387
#          Iterations 8
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         fraud_reported   No. Observations:                 1052
# Model:                          Logit   Df Residuals:                     1046
# Method:                           MLE   Df Model:                            5
# Date:                Tue, 15 Jul 2025   Pseudo R-squ.:                  0.4555
# Time:                        13:22:51   Log-Likelihood:                -397.01
# converged:                       True   LL-Null:                       -729.19
# Covariance Type:            nonrobust   LLR p-value:                2.492e-141
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                                1.4775      0.128     11.548      0.000       1.227       1.728
# insured_hobbies_chess                5.3480      0.606      8.819      0.000       4.159       6.537
# insured_hobbies_cross-fit            3.5016      0.473      7.401      0.000       2.574       4.429
# incident_severity_Minor Damage      -3.7341      0.244    -15.317      0.000      -4.212      -3.256
# incident_severity_Total Loss        -3.1838      0.233    -13.667      0.000      -3.640      -2.727
# incident_severity_Trivial Damage    -4.0719      0.507     -8.028      0.000      -5.066      -3.078
# ====================================================================================================

# %% [markdown]
# **Model Interpretation**
#
# The output summary table will provide the features used for building model along with coefficient of each of the feature and their p-value. The p-value in a logistic regression model is used to assess the statistical significance of each coefficient. Lesser the p-value, more significant the feature is in the model.
#
# A positive coefficient will indicate that an increase in the value of feature would increase the odds of the event occurring. On the other hand, a negative coefficient means the opposite, i.e, an increase in the value of feature would decrease the odds of the event occurring.

# %% [markdown]
# Now check VIFs for presence of multicollinearity in the model.

# %% [markdown]
# #### **7.2.3** Evaluate VIF of features to assess multicollinearity <font color="red">[2 Marks]</font>

# %%
# Import 'variance_inflation_factor'
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# %%
# Make a VIF DataFrame for all the variables present
vif_data = pd.DataFrame()
vif_data["feature"] = X_train_stats_const.columns

# Calculate VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X_train_stats_const.values, i)
                   for i in range(X_train_stats_const.shape[1])]

# Display VIF table
print(vif_data)
# Out:
#                             feature       VIF
# 0                             const  2.468034
# 1             insured_hobbies_chess  1.041857
# 2         insured_hobbies_cross-fit  1.020116
# 3    incident_severity_Minor Damage  1.228759
# 4      incident_severity_Total Loss  1.247809
# 5  incident_severity_Trivial Damage  1.080207

# %% [markdown]
# Proceed to the next step if p-values and VIFs are within acceptable ranges. If you observe high p-values or VIFs, drop the features and retrain the model. <font color="red">[THIS IS OPTIONAL]</font>

# %% [markdown]
# #### **7.2.4** Make predictions on training data <font color = "red">[1 Mark]</font>

# %%
# Predict the probabilities on the training data

y_train_probs = result.predict(X_train_stats_const)


# Convert to NumPy array (if needed) and reshape into a column vector
y_train_probs_array = y_train_probs.values.reshape(-1, 1)

# Reshape it into an array
print("Predicted probabilities shape:", y_train_probs_array.shape)
print("First 5 predicted probabilities:")
print(y_train_probs_array[:5])
# Out:
# Predicted probabilities shape: (1052, 1)
# First 5 predicted probabilities:
# [[0.81419588]
#  [0.15364109]
#  [0.06950041]
#  [0.09478462]
#  [0.15364109]]

# %% [markdown]
# #### **7.2.5** Create a DataFrame that includes actual fraud reported flags, predicted probabilities, and a column indicating predicted classifications based on a cutoff value of 0.5 <font color="red">[1 Mark]</font>

# %%
# Create a new DataFrame containing the actual fraud reported flag and the probabilities predicted by the model
predictions_df = pd.DataFrame({
    'Actual': y_train_filtered.values,
    'Predicted_Prob': y_train_probs
})
# Create new column indicating predicted classifications based on a cutoff value of 0.5
predictions_df['Predicted_Label'] = (predictions_df['Predicted_Prob'] >= 0.5).astype(int)

# Preview
print(predictions_df.head())
# Out:
#    Actual  Predicted_Prob  Predicted_Label
# 0       0        0.814196                1
# 1       0        0.153641                0
# 2       0        0.069500                0
# 3       0        0.094785                0
# 4       0        0.153641                0

# %% [markdown]
# **Model performance evaluation**
#
# Evaluate the performance of the model based on predictions made on the training data.

# %% [markdown]
# #### **7.2.6** Check the accuracy of the model <font color = "red">[1 Mark]</font>

# %%
# Import metrics from sklearn for evaluation
from sklearn.metrics import accuracy_score

# Check the accuracy of the model

accuracy = accuracy_score(predictions_df['Actual'], predictions_df['Predicted_Label'])

print(f"Training Accuracy of Logistic Regression Model: {accuracy:.4f}")
# Out:
# Training Accuracy of Logistic Regression Model: 0.8755

# %% [markdown]
# #### **7.2.7** Create a confusion matrix based on the predictions made on the training data <font color="red">[1 Mark]</font>

# %%
# Create confusion matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Compute the confusion matrix
cm = confusion_matrix(predictions_df['Actual'], predictions_df['Predicted_Label'])

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Legitimate (0)', 'Fraudulent (1)'])
disp.plot(cmap='Blues')

# %% [markdown]
# #### **7.2.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
cm = confusion_matrix(predictions_df['Actual'], predictions_df['Predicted_Label'])

# Assign components
TN, FP, FN, TP = cm.ravel()

# Display results
print(f"True Positives (TP): {TP}")
print(f"True Negatives (TN): {TN}")
print(f"False Positives (FP): {FP}")
print(f"False Negatives (FN): {FN}")
# Out:
# True Positives (TP): 474
# True Negatives (TN): 447
# False Positives (FP): 79
# False Negatives (FN): 52

# %% [markdown]
# #### **7.2.9** Calculate sensitivity, specificity, precision, recall and F1-score <font color="red">[2 Marks]</font>

# %%
# Calculate the sensitivity
TN, FP, FN, TP = confusion_matrix(predictions_df['Actual'], predictions_df['Predicted_Label']).ravel()
sensitivity = TP / (TP + FN)

# Calculate the specificity
specificity = TN / (TN + FP)

# Calculate Precision
precision = TP / (TP + FP)

# Calculate Recall
recall = sensitivity

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)


print(f"Sensitivity (Recall): {sensitivity:.4f}")
print(f"Specificity: {specificity:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sensitivity (Recall): 0.9011
# Specificity: 0.8498
# Precision: 0.8571
# Recall: 0.9011
# F1 Score: 0.8786

# %% [markdown]
# ### **7.3 Find the Optimal Cutoff** <font color = red>[12 marks]</font>
# Find the optimal cutoff to improve model performance by evaluating various cutoff values and their impact on relevant metrics.

# %% [markdown]
# #### **7.3.1** Plot ROC Curve  to visualise the trade-off between true positive rate and false positive rate across different classification thresholds <font color="red">[2 Marks]</font>

# %%
# Import libraries or function to plot the ROC curve

from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt


# Define ROC function
def plot_roc_curve(y_true, y_probs, title='ROC Curve'):
    # Calculate FPR (False Positive Rate), TPR (True Positive Rate), thresholds
    fpr, tpr, thresholds = roc_curve(y_true, y_probs)
    
    # Calculate AUC
    auc_score = roc_auc_score(y_true, y_probs)

    # Plot ROC curve
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {auc_score:.4f})')
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Diagonal
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(title)
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()

# %%
# Call the ROC function
plot_roc_curve(predictions_df['Actual'], predictions_df['Predicted_Prob'], title='Training ROC Curve - Logistic Regression')

# %% [markdown]
# **Sensitivity and Specificity tradeoff**
#
# After analysing the area under the curve of the ROC, check the sensitivity and specificity tradeoff to find the optimal cutoff point.

# %% [markdown]
# #### **7.3.2** Predict on training data at various probability cutoffs <font color="red">[1 Mark]</font>

# %%
# Create columns with different probability cutoffs to explore the impact of cutoff on model performance
# Define different cutoff thresholds
cutoffs = [0.3, 0.4, 0.5, 0.6, 0.7]

# Create new columns in the DataFrame for each cutoff
for cutoff in cutoffs:
    col_name = f'Pred_Label_{int(cutoff*100)}'
    predictions_df[col_name] = (predictions_df['Predicted_Prob'] >= cutoff).astype(int)

# Display the first few rows
predictions_df.head()
# Out:
#    Actual  Predicted_Prob  Predicted_Label  Pred_Label_30  Pred_Label_40  \
# 0       0        0.814196                1              1              1
# 1       0        0.153641                0              0              0
# 2       0        0.069500                0              0              0
# 3       0        0.094785                0              0              0
# 4       0        0.153641                0              0              0
#
#    Pred_Label_50  Pred_Label_60  Pred_Label_70
# 0              1              1              1
# 1              0              0              0
# 2              0              0              0
# 3              0              0              0
# 4              0              0              0

# %% [markdown]
# #### **7.3.3** Plot accuracy, sensitivity, specificity at different values of probability cutoffs <font color="red">[2 Marks]</font>

# %%
# Create a DataFrame to see the values of accuracy, sensitivity, and specificity at different values of probability cutoffs
from sklearn.metrics import confusion_matrix

# Define cutoff thresholds to evaluate
cutoffs = [0.3, 0.4, 0.5, 0.6, 0.7]

# List to store metric results
metrics = []

# Calculate metrics for each cutoff
for cutoff in cutoffs:
    predicted = (predictions_df['Predicted_Prob'] >= cutoff).astype(int)
    tn, fp, fn, tp = confusion_matrix(predictions_df['Actual'], predicted).ravel()
    
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    sensitivity = tp / (tp + fn)  # Recall
    specificity = tn / (tn + fp)
    
    metrics.append({
        'Cutoff': cutoff,
        'Accuracy': round(accuracy, 4),
        'Sensitivity (Recall)': round(sensitivity, 4),
        'Specificity': round(specificity, 4)
    })

# Create DataFrame
cutoff_metrics_df = pd.DataFrame(metrics)

# Display
print(cutoff_metrics_df)
# Out:
#    Cutoff  Accuracy  Sensitivity (Recall)  Specificity
# 0     0.3    0.8755                0.9011       0.8498
# 1     0.4    0.8755                0.9011       0.8498
# 2     0.5    0.8755                0.9011       0.8498
# 3     0.6    0.8755                0.9011       0.8498
# 4     0.7    0.8755                0.9011       0.8498

# %%
# Plot accuracy, sensitivity, and specificity at different values of probability cutoffs
import matplotlib.pyplot as plt

# Plotting the metrics
plt.figure(figsize=(10, 6))

plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Accuracy'], label='Accuracy', marker='o')
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Sensitivity (Recall)'], label='Sensitivity (Recall)', marker='o')
plt.plot(cutoff_metrics_df['Cutoff'], cutoff_metrics_df['Specificity'], label='Specificity', marker='o')

# Formatting the plot
plt.title('Model Performance at Different Probability Cutoffs')
plt.xlabel('Probability Cutoff')
plt.ylabel('Metric Value')
plt.ylim(0, 1)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #### **7.3.4** Create a column for final prediction based on optimal cutoff <font color="red">[1 Mark]</font>

# %%
# Create a column for final prediction based on the optimal cutoff
# Define your optimal cutoff — example: 0.4
optimal_cutoff = 0.4

predictions_df['Final_Prediction'] = (predictions_df['Predicted_Prob'] >= optimal_cutoff).astype(int)

# Preview the updated DataFrame
predictions_df[['Predicted_Prob', 'Final_Prediction']].head()
# Out:
#    Predicted_Prob  Final_Prediction
# 0        0.814196                 1
# 1        0.153641                 0
# 2        0.069500                 0
# 3        0.094785                 0
# 4        0.153641                 0

# %% [markdown]
# #### **7.3.5** Calculate the accuracy <font color="red">[1 Mark]</font>

# %%
# Check the accuracy now
from sklearn.metrics import accuracy_score

# Calculate accuracy of final predictions
final_accuracy = accuracy_score(predictions_df['Actual'], predictions_df['Final_Prediction'])

# Print the result
print(f"Final Accuracy at cutoff {optimal_cutoff}: {final_accuracy:.4f}")
# Out:
# Final Accuracy at cutoff 0.4: 0.8755

# %% [markdown]
# #### **7.3.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix once again
from sklearn.metrics import confusion_matrix

# Generate confusion matrix using the final prediction column
cm_final = confusion_matrix(predictions_df['Actual'], predictions_df['Final_Prediction'])

# Display the matrix
print("Confusion Matrix (Final Prediction):")
print(cm_final)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.heatmap(cm_final, annot=True, fmt='d', cmap='Blues', xticklabels=['Legit', 'Fraud'], yticklabels=['Legit', 'Fraud'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Final Prediction')
plt.show()
# Out:
# Confusion Matrix (Final Prediction):
# [[447  79]
#  [ 52 474]]

# %% [markdown]
# #### **7.3.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = confusion_matrix(predictions_df['Actual'], predictions_df['Final_Prediction']).ravel()

# Display the values
print(f"True Positives (TP): {tp}")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
# Out:
# True Positives (TP): 474
# True Negatives (TN): 447
# False Positives (FP): 79
# False Negatives (FN): 52

# %% [markdown]
# #### **7.3.8** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Mark]</font>

# %%
# Calculate Sensitivity 
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall): {sensitivity:.4f}")

# Calculate Specificity
specificity = tn / (tn + fp)
print(f"Specificity: {specificity:.4f}")

# Calculate Precision
precision = tp / (tp + fp)
print(f"Precision: {precision:.4f}")

# Calculate Recall
recall = sensitivity
print(f"Recall: {recall:.4f}")

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sensitivity (Recall): 0.9011
# Specificity: 0.8498
# Precision: 0.8571
# Recall: 0.9011
# F1 Score: 0.8786

# %% [markdown]
# **Precision and Recall tradeoff**
#
# Check optimal cutoff value by plotting precision-recall curve, and adjust the cutoff based on precision and recall tradeoff if required.

# %%
# Import precision-recall curve function
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt

# %% [markdown]
# #### **7.3.9** Plot precision-recall curve <font color="red">[1 Mark]</font>

# %%
# Plot precision-recall curve

# Get precision, recall, and threshold values
precision_vals, recall_vals, thresholds = precision_recall_curve(predictions_df['Actual'], predictions_df['Predicted_Prob'])

plt.figure(figsize=(8, 5))
plt.plot(recall_vals, precision_vals, color='blue', linewidth=2)
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **7.4 Build Random Forest Model** <font color = red>[12 marks]</font>
# Now that you have built a logistic regression model, let's move on to building a random forest model.

# %% [markdown]
# #### **7.4.1** Import necessary libraries

# %%
# Import necessary libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# #### **7.4.2** Build the random forest model <font color="red">[1 Mark]</font>

# %%
# Build a base random forest model


# Remove datetime columns from training and validation sets
datetime_cols = X_train_resampled.select_dtypes(include=['datetime64']).columns

# Drop datetime columns
X_train_rf = X_train_resampled.drop(columns=datetime_cols)
X_validation_rf = X_validation.drop(columns=datetime_cols)


X_train_resampled = X_train_resampled.astype({col: 'int' for col in X_train_resampled.select_dtypes('bool').columns})

# Convert y_validation to numeric values
y_validation_numeric = y_validation.map({'Y': 1, 'N': 0})

# Initialize the model
rf_model = RandomForestClassifier(random_state=42)

# Fit the model on the cleaned training data
rf_model.fit(X_train_rf, y_train_resampled)

# Predict on the cleaned validation set
y_pred_rf = rf_model.predict(X_validation_rf)

# Evaluate the model
print("Random Forest Accuracy:", accuracy_score(y_validation_numeric, y_pred_rf))
print("\nClassification Report:\n", classification_report(y_validation_numeric, y_pred_rf))
print("\nConfusion Matrix:\n", confusion_matrix(y_validation_numeric, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.8
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       226
#            1       0.63      0.45      0.52        74
#
#     accuracy                           0.80       300
#    macro avg       0.73      0.68      0.70       300
# weighted avg       0.79      0.80      0.79       300
#
#
# Confusion Matrix:
#  [[207  19]
#  [ 41  33]]

# %% [markdown]
# #### **7.4.3** Get feature importance scores and select important features <font color="red">[2 Marks]</font>

# %%
# Get feature importance scores from the trained model
importances = rf_model.feature_importances_

# Use the correct feature names
feature_names = rf_model.feature_names_in_

# Create a DataFrame to visualise the importance scores
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Display top 10
display(feature_importance_df.head(10))
# Out:
#                            Feature  Importance
# 70  incident_severity_Minor Damage    0.083535
# 44           insured_hobbies_chess    0.054188
# 71    incident_severity_Total Loss    0.053108
# 13                   vehicle_claim    0.050296
# 10              total_claim_amount    0.042215
# 12                  property_claim    0.042063
# 15           claim_per_vehicle_age    0.039799
# 11                    injury_claim    0.034681
# 0               months_as_customer    0.033637
# 14                       auto_year    0.028475

# %%
# Select features with high importance scores
#Step1:
importance_threshold = 0.01

# Step 2: Select features above the threshold
important_features = feature_importance_df[feature_importance_df['Importance'] > importance_threshold]['Feature'].tolist()

print("Selected important features:")
print(important_features)

# Create a new training data with only the selected features
X_train_selected = X_train_resampled[important_features]

# Confirm the shape
print("\nNew training data shape:", X_train_selected.shape)
# Out:
# Selected important features:
# ['incident_severity_Minor Damage', 'insured_hobbies_chess', 'incident_severity_Total Loss', 'vehicle_claim', 'total_claim_amount', 'property_claim', 'claim_per_vehicle_age', 'injury_claim', 'months_as_customer', 'auto_year', 'incident_hour_of_the_day', 'age', 'capital-loss', 'capital-gains', 'witnesses', 'insured_hobbies_cross-fit', 'umbrella_limit', 'bodily_injuries', 'incident_state_WV', 'policy_deductable']
#
# New training data shape: (1052, 20)

# %% [markdown]
# #### **7.4.4** Train the model with selected features <font color="red">[1 Mark]</font>

# %%
# Fit the model on the training data with selected features

# Initialize the model
rf_model_selected = RandomForestClassifier(random_state=42)

rf_model_selected.fit(X_train_selected, y_train_resampled)

print("Model trained successfully on selected important features.")
# Out:
# Model trained successfully on selected important features.

# %% [markdown]
# #### **7.4.5** Generate predictions on the training data <font color="red">[1 Mark]</font>

# %%
# Generate predictions on training data
y_train_pred_selected = rf_model_selected.predict(X_train_selected)

# Predict class probabilities
y_train_proba_selected = rf_model_selected.predict_proba(X_train_selected)[:, 1]  # Probability for class '1'

print("Predictions generated successfully.")
# Out:
# Predictions generated successfully.

# %% [markdown]
# #### **7.4.6** Check accuracy of the model <font color="red">[1 Mark]</font>

# %%
# Check accuracy of the model

accuracy_selected = accuracy_score(y_train_resampled, y_train_pred_selected)

print(f"Accuracy on training data with selected features: {accuracy_selected:.4f}")
# Out:
# Accuracy on training data with selected features: 1.0000

# %% [markdown]
# #### **7.4.7** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix to visualise the performance
cm = confusion_matrix(y_train_resampled, y_train_pred_selected)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Not Fraud', 'Fraud'])
disp.plot(cmap='Blues')

# %% [markdown]
# #### **7.4.8** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
cm = confusion_matrix(y_train_resampled, y_train_pred_selected)

# Assign values
tn, fp, fn, tp = cm.ravel()

# Print the values
print(f"True Positives (TP): {tp}")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
# Out:
# True Positives (TP): 526
# True Negatives (TN): 526
# False Positives (FP): 0
# False Negatives (FN): 0

# %% [markdown]
# #### **7.4.9** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall): {sensitivity:.4f}")

# Calculate Specificity
specificity = tn / (tn + fp)
print(f"Specificity: {specificity:.4f}")

# Calculate Precision
precision = tp / (tp + fp)
print(f"Precision: {precision:.4f}")

# Calculate Recall
recall = sensitivity
print(f"Recall: {recall:.4f}")

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print(f"F1 Score: {f1_score:.4f}")
# Out:
# Sensitivity (Recall): 1.0000
# Specificity: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000

# %% [markdown]
# #### **7.4.10** Check if the model is overfitting training data using cross validation <font color = "red">[2 marks]</font>

# %%
# Use cross validation to check if the model is overfitting

# Use the Random Forest model with selected features
rf_cv_model = RandomForestClassifier(random_state=42)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(rf_cv_model, X_train_selected, y_train_resampled, cv=5, scoring='accuracy')

# Print results
print("Cross-validation accuracies:", cv_scores)
print("Mean CV accuracy:", np.mean(cv_scores).round(4))

# Optional: Compare with training accuracy
rf_cv_model.fit(X_train_selected, y_train_resampled)
train_accuracy = rf_cv_model.score(X_train_selected, y_train_resampled)
print("Training accuracy:", round(train_accuracy, 4))
# Out:
# Cross-validation accuracies: [0.89099526 0.93838863 0.95714286 0.91904762 0.94285714]
# Mean CV accuracy: 0.9297
# Training accuracy: 1.0

# %% [markdown]
# ### **7.5 Hyperparameter Tuning** <font color = red>[10 Marks]</font>
#  Enhance the performance of the random forest model by systematically exploring and selecting optimal hyperparameter values using grid search.

# %% [markdown]
# #### **7.5.1** Use grid search to find the best hyperparameter values <font color = red>[2 Marks]</font>

# %%
# Use grid search to find the best hyperparamter values

# Define the model
rf = RandomForestClassifier(random_state=42)

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2']
}

# Setup GridSearchCV
grid_search = GridSearchCV(estimator=rf,
                           param_grid=param_grid,
                           cv=5,
                           scoring='accuracy',
                           n_jobs=-1,  # use all processors
                           verbose=1)

# Fit on training data with selected features
grid_search.fit(X_train_selected, y_train_resampled)

# Best Hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)
print("Best Cross-Validated Accuracy:", round(grid_search.best_score_, 4))
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best Hyperparameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Best Cross-Validated Accuracy: 0.9297

# %% [markdown]
# #### **7.5.2** Build a random forest model based on hyperparameter tuning results <font color = red>[1 Mark]</font>

# %%
# Building random forest model based on results of hyperparameter tuning
best_rf_model = RandomForestClassifier(
    n_estimators=200,
    max_depth=10,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features='sqrt',
    random_state=42
)

# Fit the model on the selected features of resampled training data
best_rf_model.fit(X_train_selected, y_train_resampled)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=200, random_state=42)

# %% [markdown]
# #### **7.5.3** Make predictions on training data <font color = red>[1 Mark]</font>

# %%
# Make predictions on training data
# Predict class labels
y_train_pred = best_rf_model.predict(X_train_selected)

# Predict probabilities (if needed for ROC, etc.)
y_train_proba = best_rf_model.predict_proba(X_train_selected)[:, 1]

# %% [markdown]
# #### **7.5.4** Check accuracy of Random Forest Model <font color = red>[1 Mark]</font>

# %%
# Check the accuracy
train_accuracy = accuracy_score(y_train_resampled, y_train_pred)

print(f"Training Accuracy: {train_accuracy:.4f}")
# Out:
# Training Accuracy: 0.9705

# %% [markdown]
# #### **7.5.5** Create confusion matrix <font color = red>[1 Mark]</font>

# %%
# Create the confusion matrix
cm = confusion_matrix(y_train_resampled, y_train_pred)

# Display confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[496  30]
#  [  1 525]]

# %% [markdown]
# #### **7.5.6** Create variables for true positive, true negative, false positive and false negative <font color = red>[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = cm.ravel()

# Display values
print("True Negatives (TN):", tn)
print("False Positives (FP):", fp)
print("False Negatives (FN):", fn)
print("True Positives (TP):", tp)
# Out:
# True Negatives (TN): 496
# False Positives (FP): 30
# False Negatives (FN): 1
# True Positives (TP): 525

# %% [markdown]
# #### **7.5.7** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color = red>[3 Marks]</font>

# %%
# Calculate the Sensitivity (Recall)
sensitivity = tp / (tp + fn)

# Calculate the Specificity
specificity = tn / (tn + fp)

# Calculate Precision
precision = tp / (tp + fp)

# Calculate Recall 
recall = sensitivity

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)

# Print results
print("Sensitivity (Recall):", round(sensitivity, 4))
print("Specificity:", round(specificity, 4))
print("Precision:", round(precision, 4))
print("Recall:", round(recall, 4))
print("F1 Score:", round(f1_score, 4))
# Out:
# Sensitivity (Recall): 0.9981
# Specificity: 0.943
# Precision: 0.9459
# Recall: 0.9981
# F1 Score: 0.9713

# %% [markdown]
# ## **8. Prediction and Model Evaluation** <font color = red>[20 marks]</font>
# Use the model from the previous step to make predictions on the validation data with the optimal cutoff. Then evaluate the model's performance using metrics such as accuracy, sensitivity, specificity, precision, and recall.

# %% [markdown]
# ### **8.1 Make predictions over validation data using logistic regression model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.1.1** Select relevant features for validation data and add constant <font color="red">[1 Mark]</font>

# %%
# Select the relevant features for validation data
X_validation_selected = X_validation[important_features] 
# Add constant to X_validation

import statsmodels.api as sm

# Add a constant term
X_validation_const = sm.add_constant(X_validation_selected)

# %% [markdown]
# #### **8.1.2** Make predictions over validation data <font color="red">[1 Mark]</font>

# %%
# Make predictions on the validation data and store it in the variable 'y_validation_pred'

X_validation_selected = X_validation[['insured_hobbies_chess', 'insured_hobbies_cross-fit',
                                      'incident_severity_Minor Damage', 'incident_severity_Total Loss',
                                      'incident_severity_Trivial Damage']]

# Add constant term
X_validation_const = sm.add_constant(X_validation_selected)


X_validation_const = X_validation_const.astype({col: 'int' for col in X_validation_const.select_dtypes('bool').columns})

X_validation_const = X_validation_const.apply(pd.to_numeric, errors='coerce')
X_validation_const = X_validation_const.dropna()

print("Validation shape:", X_validation_const.shape)
print("Model params shape:", result.params.shape)

y_validation_pred_prob = result.predict(X_validation_const)


optimal_cutoff = 0.5  
y_validation_pred = (y_validation_pred_prob >= optimal_cutoff).astype(int)
# Out:
# Validation shape: (300, 6)
# Model params shape: (6,)

# %% [markdown]
# #### **8.1.3** Create DataFrame with actual values and predicted values for validation data <font color="red">[2 Marks]</font>

# %%
#  Create DataFrame with actual values and predicted values for validation data


y_validation_aligned = y_validation.loc[X_validation_const.index].replace({'Y': 1, 'N': 0}).astype(int)



validation_results_df = pd.DataFrame({
    'Actual': y_validation_aligned.astype(int),
    'Predicted_Prob': y_validation_pred_prob,
    'Predicted_Label': y_validation_pred
})

# Display the first few rows
validation_results_df.head()
# Out:
#      Actual  Predicted_Prob  Predicted_Label
# 937       0        0.153641                0
# 232       0        0.153641                0
# 640       0        0.153641                0
# 469       0        0.094785                0
# 979       0        0.153641                0

# %% [markdown]
# #### **8.1.4** Make final prediction based on cutoff value <font color="red">[1 Mark]</font>

# %%
# Make final predictions on the validation data using the optimal cutoff
y_validation_pred_prob = result.predict(X_validation_const)

# Apply the optimal cutoff to get final predicted labels
optimal_cutoff=0.5
y_validation_final_pred = (y_validation_pred_prob >= optimal_cutoff).astype(int)

# Combine actual, predicted probabilities, and final predictions into a DataFrame
y_validation_aligned = y_validation.loc[X_validation_const.index].replace({'Y': 1, 'N': 0}).astype(int)

final_validation_df = pd.DataFrame({
    'Actual': y_validation_aligned,
    'Predicted_Prob': y_validation_pred_prob,
    'Final_Prediction': y_validation_final_pred
})

# Show the first few rows
final_validation_df.head()
# Out:
#      Actual  Predicted_Prob  Final_Prediction
# 937       0        0.153641                 0
# 232       0        0.153641                 0
# 640       0        0.153641                 0
# 469       0        0.094785                 0
# 979       0        0.153641                 0

# %% [markdown]
# #### **8.1.5** Check the accuracy of logistic regression model on validation data <font color="red">[1 Mark]</font>

# %%
# Check the accuracy
accuracy = accuracy_score(final_validation_df['Actual'], final_validation_df['Final_Prediction'])

print(f"Accuracy of the logistic regression model on validation data: {accuracy:.4f}")
# Out:
# Accuracy of the logistic regression model on validation data: 0.8400

# %% [markdown]
# #### **8.1.6** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix
cm = confusion_matrix(final_validation_df['Actual'], final_validation_df['Final_Prediction'])

# Display the confusion matrix
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[188  38]
#  [ 10  64]]

# %% [markdown]
# #### **8.1.7** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
tn, fp, fn, tp = confusion_matrix(final_validation_df['Actual'], final_validation_df['Final_Prediction']).ravel()

# Print the results
print(f"True Positives (TP): {tp}")
print(f"True Negatives (TN): {tn}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
# Out:
# True Positives (TP): 64
# True Negatives (TN): 188
# False Positives (FP): 38
# False Negatives (FN): 10

# %% [markdown]
# #### **8.1.8** Calculate sensitivity, specificity, precision, recall and f1 score of the model <font color="red">[2 Marks]</font>

# %%
# Calculate Sensitivity
sensitivity = tp / (tp + fn)
print(f"Sensitivity (Recall): {sensitivity:.3f}")

# Calculate Specificity
specificity = tn / (tn + fp)
print(f"Specificity: {specificity:.3f}")

# Calculate Precision
precision = tp / (tp + fp)
print(f"Precision: {precision:.3f}")

# Calculate Recall
recall = sensitivity
print(f"Recall: {recall:.3f}")

# Calculate F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print(f"F1 Score: {f1_score:.3f}")
# Out:
# Sensitivity (Recall): 0.865
# Specificity: 0.832
# Precision: 0.627
# Recall: 0.865
# F1 Score: 0.727

# %% [markdown]
# ### **8.2 Make predictions over validation data using random forest model** <font color = red>[10 marks]</font>

# %% [markdown]
# #### **8.2.1** Select the important features and make predictions over validation data <font color="red">[2 Marks]</font>

# %%
# Select the relevant features for validation data


selected_features = X_train_selected.columns 
X_validation_selected = X_validation[selected_features]


X_validation_selected = X_validation_selected.astype({col: 'int' for col in X_validation_selected.select_dtypes('bool').columns})

X_validation_selected = X_validation_selected.apply(pd.to_numeric, errors='coerce')

# Drop any rows with NaNs (if any appear)
X_validation_selected = X_validation_selected.dropna()

# Make predictions on the validation data

y_validation_pred_rf = best_rf_model.predict(X_validation_selected)

# Predict probabilities (optional, for ROC/AUC or threshold tuning)
y_validation_pred_prob_rf = best_rf_model.predict_proba(X_validation_selected)[:, 1]

# %% [markdown]
# #### **8.2.2** Check accuracy of random forest model <font color="red">[1 Mark]</font>

# %%
# Check accuracy

accuracy_rf = accuracy_score(y_validation_numeric, y_validation_pred_rf)

print(f"Random Forest Accuracy on Validation Set: {accuracy_rf:.4f}")
# Out:
# Random Forest Accuracy on Validation Set: 0.8333

# %% [markdown]
# #### **8.2.3** Create confusion matrix <font color="red">[1 Mark]</font>

# %%
# Create the confusion matrix

conf_matrix = confusion_matrix(y_validation_numeric, y_validation_pred_rf)

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[193  33]
#  [ 17  57]]

# %% [markdown]
# #### **8.2.4** Create variables for true positive, true negative, false positive and false negative <font color="red">[1 Mark]</font>

# %%
# Create variables for true positive, true negative, false positive and false negative
conf_matrix = confusion_matrix(y_validation_numeric, y_validation_pred_rf)

# Assign values
tn, fp, fn, tp = conf_matrix.ravel()

# Print values
print("True Positives (TP):", tp)
print("True Negatives (TN):", tn)
print("False Positives (FP):", fp)
print("False Negatives (FN):", fn)
# Out:
# True Positives (TP): 57
# True Negatives (TN): 193
# False Positives (FP): 33
# False Negatives (FN): 17

# %% [markdown]
# #### **8.2.5** Calculate sensitivity, specificity, precision, recall and F1-score of the model <font color="red">[5 Marks]</font>

# %%
#Calculate Sensitivity
sensitivity = tp / (tp + fn)
print("Sensitivity (Recall):", round(sensitivity, 4))

#Calculate  Specificity 
specificity = tn / (tn + fp)
print("Specificity:", round(specificity, 4))

#Calculate  Precision 
precision = tp / (tp + fp)
print("Precision:", round(precision, 4))

#Calculate  Recall
recall = sensitivity
print("Recall:", round(recall, 4))

#Calculate  F1 Score
f1_score = 2 * (precision * recall) / (precision + recall)
print("F1 Score:", round(f1_score, 4))
# Out:
# Sensitivity (Recall): 0.7703
# Specificity: 0.854
# Precision: 0.6333
# Recall: 0.7703
# F1 Score: 0.6951

# %% [markdown]
# ## **Evaluation and Conclusion**
# Write the conclusion.

# %% [markdown]
# ## <font color="blue">**Evaluation:**</font>
#
# *Logistic Regression Model*
#
# Features Used: After feature selection using RFECV and statistical significance, the logistic model was built with selected features including:
#
# 1	insured_hobbies_chess
#
# 2	insured_hobbies_cross-fit
#
# 3	incident_severity_Minor Damage
#
# 4	incident_severity_Total Loss
#
# 5	incident_severity_Trivial Damage
#
# 6	Model Fit Summary:
#
# 7	All coefficients were statistically significant (p < 0.05).
#
# 8	Pseudo R² = 0.4555, indicating decent explanatory power for a classification problem.
#
#
# *Multicollinearity:*
#
# 1	VIF values were all < 2, suggesting no multicollinearity issues.
#
# 2	Performance Metrics on Validation Set (based on optimal cutoff):
#
# 3	Accuracy: Acceptable but slightly lower than random forest.
#
# 4	Precision & Recall: Balanced but lower than RF.
#
# 5	F1 Score: Good, but RF slightly outperformed.
#
# 6	Interpretability: Very high. Logistic regression offers clear insight into how each variable affects the prediction.
#
#
# *Random Forest Model:*
#
# 1	Feature Engineering: Used all encoded features from training data.
#
# 2	Model Tuning: Hyperparameter tuning via Grid Search improved model accuracy and generalization.
#
# 3	Feature Importance:
#
# 4	The most impactful variables were identified, useful for feature reduction.
#
# 5	Performance on Validation Set:
#
# 6	Accuracy: Higher than logistic regression.
#
# 7	Precision: Higher (fewer false positives).
#
# 8	Recall (Sensitivity): Also higher — better at identifying fraud.
#
# 9	F1 Score: Slightly better than logistic model, indicating strong balance between precision and recall.
#
# *Interpretability:* Lower compared to logistic regression due to model complexity.
#
#
# ## <font color="blue">**Conclusion:** </font>
#
# If interpretability is key, go with Logistic Regression.
#
# If predictive performance is the priority, especially in fraud detection, where catching fraudulent cases is crucial, Random Forest is the better choice due to:
#
# Higher recall
#
# Better precision
#
# Stronger overall performance
